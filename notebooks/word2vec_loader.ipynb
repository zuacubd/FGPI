# %%
import os
import json

#import spacy

from gensim.test.utils import datapath
from gensim.models import Word2Vec, KeyedVectors

## reading and writing data    
def get_file_content(path):
    with open(path, 'r') as f:
        lines = f.read().splitlines()
    return lines

def get_json_content(path):
    with open(path, 'r') as f:
        json_data = json.load(f)
    
    data = json.loads(json_data)
    return data

#loading models
def load_spacy_nlp(model_name):
    return spacy.load(model_name)

def load_word2vec_model(model_path):
    return KeyedVectors.load_word2vec_format(datapath(model_path), binary=True, unicode_errors='ignore')

def get_lexicon(lexicon_contents):
    return lexicon_contents[1:]
    
## processing

def word2vec_similar_topk(model, word, topk):
    return model.most_similar(word, topn=topk)


def get_pos_tags_word2vec_terms(lexicon_list):
    vocab_features = {}
    lexicons = ' '.join(lexicon_list)
    doc = nlp(lexicons)
    
    with open(data_dir+'results/lexicons_postag_word2vecterms.txt', 'w') as fr:
        
        fr.write('Keyphrase,POS,Tag,Word2VecTerms\n')
        for token in doc:
            #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
            fr.write(token.text +',' + token.pos_ + ',' + token.tag_)
            print (token.text +',' + token.pos_ + ',' + token.tag_)
            if token.text in word2vec_model:
                #print(token.text, token.pos_, token.tag_, 'Found')
                similar_word_weight = word2vec_similar_topk(word2vec_model, token.text, 100)
                words = [item[0] for item in similar_word_weight if item[1]>0.6]
                weights = [item[1] for item in similar_word_weight if item[1]>0.6] 
                
                word_weight = [words[wdx]+'_'+str(weights[wdx]) for wdx in range(0, len(words))]
                line = ' '.join(word_weight)
                fr.write(','+line+'\n')
                print (line)
                #print ("{}".format(similar_word_weight))
                #fr.write('\tFound'+'\n')
            else:
                fr.write('\tNot found'+'\n')
                #print(token.text, token.pos_, token.tag_, 'Not Found')
                #print ("{} is not found".format(token))        

def get_pos_tags(lexicon_list):
    vocab_features = {}
    lexicons = ' '.join(lexicon_list)
    doc = nlp(lexicons)
    
    with open(data_dir+'results/lexicons_postag_isword2vecvocab.txt', 'w') as fr:
        for token in doc:
            #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
            fr.write(token.text +'\t' + token.pos_ + '\t' + token.tag_)
            if token.text in word2vec_model:
                #print(token.text, token.pos_, token.tag_, 'Found')
                #similar_word_weight = word2vec_similar_topk(word2vec_model, token.text, 5)
                #print ("{}".format(similar_word_weight))
                fr.write('\tFound'+'\n')
            else:
                fr.write('\tNot found'+'\n')
                #print(token.text, token.pos_, token.tag_, 'Not Found')
                #print ("{} is not found".format(token))        
    
def get_google_word2vec_space(lexicon_list):    
    #with open(data_dir+'results/lexicons_tag.txt', 'w') as fr:
    count = 0
    for token in lexicon_list:
        if token in word2vec_model:
            print ("{} is in the google word2vec space".format(token))
            count = count + 1
        else:
            print ("{} is not found".format(token))      
    rate_of_exist = count/len(lexicon_list)
    return rate_of_exist


def get_twitter_word2vec_space(lexicon_list):    
    #with open(data_dir+'results/lexicons_tag.txt', 'w') as fr:
    count = 0
    for token in lexicon_list:
        if token in word2vec_twitter or token.lower() in word2vec_twitter:
            print ("{} is in the twitter word2vec space".format(token))
            count = count + 1
        else:
            print ("{} is not found".format(token))
    
    rate_of_exist = count/len(lexicon_list)
    return rate_of_exist


print ("setting up the data path ...")
data_dir = "/projets/sig/mullah/nlp/fgpi/"
figures_path ='../figures/'
graph_dir = "/projets/sig/mullah/nlp/fgpi/graph"
lexicon_name='Radical'

#newretweetuserid_neworiginaluserid_path = os.path.join(data_dir, 'data/processed/20000_UserRetweetID_UserOriginalID_NewID.txt')
#tweetID_msg_path = os.path.join(data_dir, 'data/processed/20000_id_OriginalTweet.json')
#retweetUserID_tweetUserID_tweetID_path = os.path.join(data_dir, 'data/processed/20000_UserRetweet_UserOriginal_idOriginalTweet.txt')
#retweetUserID_tweetUserID_tweetID_path = os.path.join(data_dir, 'data/processed/20000_RetweetUserNewID_TweetUserNewID_TweetID.txt')

lexicon_path = os.path.join(data_dir, 'lexicons/'+lexicon_name)
#word2vec_model_path = ""
word2vec_google_model_path = '/projets/sig/mullah/ir/data/word_embedding/pretrain/word2vec/googlenews/GoogleNews-vectors-negative300.bin'
word2vec_twitter_model_path = '/projets/sig/mullah/ir/data/word_embedding/pretrain/twitter/word2vec_twitter_tokens.bin'

#loading models
#nlp = load_spacy_nlp('en_core_web_sm')
word2vec_model = load_word2vec_model(word2vec_google_model_path)
word2vec_twitter = load_word2vec_model(word2vec_twitter_model_path)

#word2vec_twitter = KeyedVectors.load_word2vec_format(word2vec_twitter_model_path, binary=True, unicode_errors='ignore')
#lexicon_path = os.path.join(data_dir, 'lexicons/Islamism')

lexicon_contents = get_file_content(lexicon_path)
lexicon_list = get_lexicon(lexicon_contents)
print ("Total jargons in lexicon: {}".format(len(lexicon_list)))
print (lexicon_list)

#get_pos_tags(lexicon_list)
rate_of_exist_google = get_google_word2vec_space(lexicon_list)
print (rate_of_exist_google)
rate_of_exist_twitter = get_twitter_word2vec_space(lexicon_list)
print (rate_of_exist_twitter)

#get_pos_tags_word2vec_terms(lexicon_list)
# Out:
# setting up the data path ...
# Total jargons in lexicon: 188
# ['#CountrysideCleanup', '#Islam', '#MyJihad', '#SpringJihad', 'airstrike', 'alal-Jihad', 'aleppo', 'aleppo', 'allah', 'army', 'Ash-Sham', 'assad', 'attack', 'battlefield', 'break', 'claim', 'Victory', 'cynthiastruth', 'destroy', 'extreme', 'Extremists', 'Fight', 'fight', 'Haya', 'fight', 'Haya ala-Jihad', 'Iraq', 'IS', 'isil', 'islam', 'Islamic State', 'Jihad', 'kafir', 'Khalifah', 'Kill', 'Killing', 'Leaders', 'libya', 'martyrdom', 'mosul', 'Mujaheddin', 'Muslim', 'paradise ', 'pray', 'rebel', 'Rise', 'Slaughter', 'soldier', 'State', 'support', 'syria', 'Terrorism', 'ummah', 'victory', 'war', 'Brutality', 'beheaded', 'execute', 'punish', 'warning', 'admonish', 'Beheading', 'knife', 'camera', 'muja?hidi?n', 'Western troops', 'Khila?fah', 'ka?fir', 'crusader', 'war', 'Europe', 'behead', '#islamicstate', 'Crusade', 'captivity', 'enemy', 'revenge', 'killing', 'brother', 'Knife attack', 'kill', 'kills', 'killed', 'muja?hid', 'man', 'knife', 'Allah', 'Muslim', 'crusader', 'blood', 'defense', 'Messenger', 'man', 'Zarqawi', 'boarder-crossing', 'operation', 'operations', 'mujahidun', 'attacking', 'attack', 'Jewish', 'stabbed', 'slaughter', 'Crusader', 'apostates', 'brother', 'kuffar', 'weapon', 'dagger', 'blade', 'sharpness', 'cutting', 'metal', 'slicing', 'Vehicle attack', 'takfir', 'cars', 'filled', 'explosives', 'armed', 'fight', 'enemies', 'soldiers', 'weapon', 'attack', 'high speed', 'congregation', 'kuffar', 'smashing', 'bodies', 'crushing', 'wheels', 'location', 'place', 'pedestrians', 'vehicles', 'center', 'celebrations', 'targets', 'streets', 'homosexuals', 'homos ', 'gays', 'queers', 'homosexuals', 'homosexuality', 'fags', 'homo', 'pedophiles', 'fag ', 'perverts', 'pedophilia', 'wn', 'queer ', 'sodomites', 'heterosexual', 'perversion', 'faggots', 'jew', 'heterosexuals', 'lesbians', 'adl', 'faggotry', 'sodomy', 'molestation', 'faggot', 'degenerates', 'molesters', 'splc', 'zog', 'negroes', 'bisexual', 'molest ', 'disgusting', 'nambla', 'filth', 'whites', 'degenerate ', 'Aryan', 'multiculturalism ', 'race', 'idealists', 'homeland', 'sabotage ', 'railways', 'Revolution', 'capital', 'Comrades']
# #CountrysideCleanup is not found
# #Islam is not found
# #MyJihad is not found
# #SpringJihad is not found
# airstrike is in the google word2vec space
# alal-Jihad is not found
# aleppo is not found
# aleppo is not found
# allah is in the google word2vec space
# army is in the google word2vec space
# Ash-Sham is not found
# assad is not found
# attack is in the google word2vec space
# battlefield is in the google word2vec space
# break is in the google word2vec space
# claim is in the google word2vec space
# Victory is in the google word2vec space
# cynthiastruth is not found
# destroy is in the google word2vec space
# extreme is in the google word2vec space
# Extremists is in the google word2vec space
# Fight is in the google word2vec space
# fight is in the google word2vec space
# Haya is in the google word2vec space
# fight is in the google word2vec space
# Haya ala-Jihad is not found
# Iraq is in the google word2vec space
# IS is in the google word2vec space
# isil is not found
# islam is in the google word2vec space
# Islamic State is not found
# Jihad is in the google word2vec space
# kafir is in the google word2vec space
# Khalifah is in the google word2vec space
# Kill is in the google word2vec space
# Killing is in the google word2vec space
# Leaders is in the google word2vec space
# libya is in the google word2vec space
# martyrdom is in the google word2vec space
# mosul is not found
# Mujaheddin is in the google word2vec space
# Muslim is in the google word2vec space
# paradise  is not found
# pray is in the google word2vec space
# rebel is in the google word2vec space
# Rise is in the google word2vec space
# Slaughter is in the google word2vec space
# soldier is in the google word2vec space
# State is in the google word2vec space
# support is in the google word2vec space
# syria is in the google word2vec space
# Terrorism is in the google word2vec space
# ummah is in the google word2vec space
# victory is in the google word2vec space
# war is in the google word2vec space
# Brutality is in the google word2vec space
# beheaded is in the google word2vec space
# execute is in the google word2vec space
# punish is in the google word2vec space
# warning is in the google word2vec space
# admonish is in the google word2vec space
# Beheading is in the google word2vec space
# knife is in the google word2vec space
# camera is in the google word2vec space
# muja?hidi?n is not found
# Western troops is not found
# Khila?fah is not found
# ka?fir is not found
# crusader is in the google word2vec space
# war is in the google word2vec space
# Europe is in the google word2vec space
# behead is in the google word2vec space
# #islamicstate is not found
# Crusade is in the google word2vec space
# captivity is in the google word2vec space
# enemy is in the google word2vec space
# revenge is in the google word2vec space
# killing is in the google word2vec space
# brother is in the google word2vec space
# Knife attack is not found
# kill is in the google word2vec space
# kills is in the google word2vec space
# killed is in the google word2vec space
# muja?hid is not found
# man is in the google word2vec space
# knife is in the google word2vec space
# Allah is in the google word2vec space
# Muslim is in the google word2vec space
# crusader is in the google word2vec space
# blood is in the google word2vec space
# defense is in the google word2vec space
# Messenger is in the google word2vec space
# man is in the google word2vec space
# Zarqawi is in the google word2vec space
# boarder-crossing is not found
# operation is in the google word2vec space
# operations is in the google word2vec space
# mujahidun is not found
# attacking is in the google word2vec space
# attack is in the google word2vec space
# Jewish is in the google word2vec space
# stabbed is in the google word2vec space
# slaughter is in the google word2vec space
# Crusader is in the google word2vec space
# apostates is in the google word2vec space
# brother is in the google word2vec space
# kuffar is in the google word2vec space
# weapon is in the google word2vec space
# dagger is in the google word2vec space
# blade is in the google word2vec space
# sharpness is in the google word2vec space
# cutting is in the google word2vec space
# metal is in the google word2vec space
# slicing is in the google word2vec space
# Vehicle attack is not found
# takfir is in the google word2vec space
# cars is in the google word2vec space
# filled is in the google word2vec space
# explosives is in the google word2vec space
# armed is in the google word2vec space
# fight is in the google word2vec space
# enemies is in the google word2vec space
# soldiers is in the google word2vec space
# weapon is in the google word2vec space
# attack is in the google word2vec space
# high speed is not found
# congregation is in the google word2vec space
# kuffar is in the google word2vec space
# smashing is in the google word2vec space
# bodies is in the google word2vec space
# crushing is in the google word2vec space
# wheels is in the google word2vec space
# location is in the google word2vec space
# place is in the google word2vec space
# pedestrians is in the google word2vec space
# vehicles is in the google word2vec space
# center is in the google word2vec space
# celebrations is in the google word2vec space
# targets is in the google word2vec space
# streets is in the google word2vec space
# homosexuals is in the google word2vec space
# homos  is not found
# gays is in the google word2vec space
# queers is in the google word2vec space
# homosexuals is in the google word2vec space
# homosexuality is in the google word2vec space
# fags is in the google word2vec space
# homo is in the google word2vec space
# pedophiles is in the google word2vec space
# fag  is not found
# perverts is in the google word2vec space
# pedophilia is in the google word2vec space
# wn is in the google word2vec space
# queer  is not found
# sodomites is in the google word2vec space
# heterosexual is in the google word2vec space
# perversion is in the google word2vec space
# faggots is not found
# jew is in the google word2vec space
# heterosexuals is in the google word2vec space
# lesbians is in the google word2vec space
# adl is in the google word2vec space
# faggotry is in the google word2vec space
# sodomy is in the google word2vec space
# molestation is in the google word2vec space
# faggot is not found
# degenerates is in the google word2vec space
# molesters is in the google word2vec space
# splc is not found
# zog is not found
# negroes is in the google word2vec space
# bisexual is in the google word2vec space
# molest  is not found
# disgusting is in the google word2vec space
# nambla is not found
# filth is in the google word2vec space
# whites is in the google word2vec space
# degenerate  is not found
# Aryan is in the google word2vec space
# multiculturalism  is not found
# race is in the google word2vec space
# idealists is in the google word2vec space
# homeland is in the google word2vec space
# sabotage  is not found
# railways is in the google word2vec space
# Revolution is in the google word2vec space
# capital is in the google word2vec space
# Comrades is in the google word2vec space
# 0.7978723404255319
# #CountrysideCleanup is not found
# #Islam is in the twitter word2vec space
# #MyJihad is in the twitter word2vec space
# #SpringJihad is not found
# airstrike is in the twitter word2vec space
# alal-Jihad is not found
# aleppo is in the twitter word2vec space
# aleppo is in the twitter word2vec space
# allah is in the twitter word2vec space
# army is in the twitter word2vec space
# Ash-Sham is in the twitter word2vec space
# assad is in the twitter word2vec space
# attack is in the twitter word2vec space
# battlefield is in the twitter word2vec space
# break is in the twitter word2vec space
# claim is in the twitter word2vec space
# Victory is in the twitter word2vec space
# cynthiastruth is not found
# destroy is in the twitter word2vec space
# extreme is in the twitter word2vec space
# Extremists is in the twitter word2vec space
# Fight is in the twitter word2vec space
# fight is in the twitter word2vec space
# Haya is in the twitter word2vec space
# fight is in the twitter word2vec space
# Haya ala-Jihad is not found
# Iraq is in the twitter word2vec space
# IS is in the twitter word2vec space
# isil is in the twitter word2vec space
# islam is in the twitter word2vec space
# Islamic State is not found
# Jihad is in the twitter word2vec space
# kafir is in the twitter word2vec space
# Khalifah is in the twitter word2vec space
# Kill is in the twitter word2vec space
# Killing is in the twitter word2vec space
# Leaders is in the twitter word2vec space
# libya is in the twitter word2vec space
# martyrdom is in the twitter word2vec space
# mosul is in the twitter word2vec space
# Mujaheddin is in the twitter word2vec space
# Muslim is in the twitter word2vec space
# paradise  is not found
# pray is in the twitter word2vec space
# rebel is in the twitter word2vec space
# Rise is in the twitter word2vec space
# Slaughter is in the twitter word2vec space
# soldier is in the twitter word2vec space
# State is in the twitter word2vec space
# support is in the twitter word2vec space
# syria is in the twitter word2vec space
# Terrorism is in the twitter word2vec space
# ummah is in the twitter word2vec space
# victory is in the twitter word2vec space
# war is in the twitter word2vec space
# Brutality is in the twitter word2vec space
# beheaded is in the twitter word2vec space
# execute is in the twitter word2vec space
# punish is in the twitter word2vec space
# warning is in the twitter word2vec space
# admonish is in the twitter word2vec space
# Beheading is in the twitter word2vec space
# knife is in the twitter word2vec space
# camera is in the twitter word2vec space
# muja?hidi?n is not found
# Western troops is not found
# Khila?fah is not found
# ka?fir is not found
# crusader is in the twitter word2vec space
# war is in the twitter word2vec space
# Europe is in the twitter word2vec space
# behead is in the twitter word2vec space
# #islamicstate is not found
# Crusade is in the twitter word2vec space
# captivity is in the twitter word2vec space
# enemy is in the twitter word2vec space
# revenge is in the twitter word2vec space
# killing is in the twitter word2vec space
# brother is in the twitter word2vec space
# Knife attack is not found
# kill is in the twitter word2vec space
# kills is in the twitter word2vec space
# killed is in the twitter word2vec space
# muja?hid is not found
# man is in the twitter word2vec space
# knife is in the twitter word2vec space
# Allah is in the twitter word2vec space
# Muslim is in the twitter word2vec space
# crusader is in the twitter word2vec space
# blood is in the twitter word2vec space
# defense is in the twitter word2vec space
# Messenger is in the twitter word2vec space
# man is in the twitter word2vec space
# Zarqawi is in the twitter word2vec space
# boarder-crossing is not found
# operation is in the twitter word2vec space
# operations is in the twitter word2vec space
# mujahidun is not found
# attacking is in the twitter word2vec space
# attack is in the twitter word2vec space
# Jewish is in the twitter word2vec space
# stabbed is in the twitter word2vec space
# slaughter is in the twitter word2vec space
# Crusader is in the twitter word2vec space
# apostates is in the twitter word2vec space
# brother is in the twitter word2vec space
# kuffar is in the twitter word2vec space
# weapon is in the twitter word2vec space
# dagger is in the twitter word2vec space
# blade is in the twitter word2vec space
# sharpness is in the twitter word2vec space
# cutting is in the twitter word2vec space
# metal is in the twitter word2vec space
# slicing is in the twitter word2vec space
# Vehicle attack is not found
# takfir is in the twitter word2vec space
# cars is in the twitter word2vec space
# filled is in the twitter word2vec space
# explosives is in the twitter word2vec space
# armed is in the twitter word2vec space
# fight is in the twitter word2vec space
# enemies is in the twitter word2vec space
# soldiers is in the twitter word2vec space
# weapon is in the twitter word2vec space
# attack is in the twitter word2vec space
# high speed is not found
# congregation is in the twitter word2vec space
# kuffar is in the twitter word2vec space
# smashing is in the twitter word2vec space
# bodies is in the twitter word2vec space
# crushing is in the twitter word2vec space
# wheels is in the twitter word2vec space
# location is in the twitter word2vec space
# place is in the twitter word2vec space
# pedestrians is in the twitter word2vec space
# vehicles is in the twitter word2vec space
# center is in the twitter word2vec space
# celebrations is in the twitter word2vec space
# targets is in the twitter word2vec space
# streets is in the twitter word2vec space
# homosexuals is in the twitter word2vec space
# homos  is not found
# gays is in the twitter word2vec space
# queers is in the twitter word2vec space
# homosexuals is in the twitter word2vec space
# homosexuality is in the twitter word2vec space
# fags is in the twitter word2vec space
# homo is in the twitter word2vec space
# pedophiles is in the twitter word2vec space
# fag  is not found
# perverts is in the twitter word2vec space
# pedophilia is in the twitter word2vec space
# wn is in the twitter word2vec space
# queer  is not found
# sodomites is in the twitter word2vec space
# heterosexual is in the twitter word2vec space
# perversion is in the twitter word2vec space
# faggots is in the twitter word2vec space
# jew is in the twitter word2vec space
# heterosexuals is in the twitter word2vec space
# lesbians is in the twitter word2vec space
# adl is in the twitter word2vec space
# faggotry is in the twitter word2vec space
# sodomy is in the twitter word2vec space
# molestation is in the twitter word2vec space
# faggot is in the twitter word2vec space
# degenerates is in the twitter word2vec space
# molesters is in the twitter word2vec space
# splc is in the twitter word2vec space
# zog is in the twitter word2vec space
# negroes is in the twitter word2vec space
# bisexual is in the twitter word2vec space
# molest  is not found
# disgusting is in the twitter word2vec space
# nambla is not found
# filth is in the twitter word2vec space
# whites is in the twitter word2vec space
# degenerate  is not found
# Aryan is in the twitter word2vec space
# multiculturalism  is not found
# race is in the twitter word2vec space
# idealists is in the twitter word2vec space
# homeland is in the twitter word2vec space
# sabotage  is not found
# railways is in the twitter word2vec space
# Revolution is in the twitter word2vec space
# capital is in the twitter word2vec space
# Comrades is in the twitter word2vec space
# 0.8617021276595744
